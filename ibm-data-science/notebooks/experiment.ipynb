# %% [markdown]
# ## Module 1
# These are the testing area when I learn Types, String operations, indexing in Python

# %%
print("hello nanta")
# Out:
# hello nanta

# %%
a = [1, 2, 3, 4, 5]
b = [-1, -2, -3, -4, -5]

# %%
import matplotlib.pyplot as plt
plt.plot(a,b)
plt.show()

# %%
type(6/2)
# Out:
# float

# %%
type(6//2)
# Out:
# int

# %%
type("Hello" == "World")
# Out:
# bool

# %%
str("123-456-7890")
# Out:
# '123-456-7890'

# %%
a="Maria"
b="Rodri"

z=a+b

print(f"{a} {b}")
# Out:
# Maria Rodri

# %%
"Maria" + "" + "Rodri"
# Out:
# 'MariaRodri'

# %%
a="data science basic"

a.title()
# Out:
# 'Data Science Basic'

# %%
 print("Python is \"awesome\"")
# Out:
# Python is "awesome"

# %% [markdown]
# ## Module 2
# Below this will be the area where I testing when I was learning Tuples

# %%
testuple1="Word1",1,3.1

print(testuple1[0])
# Out:
# Word1

# %%
tuple2=testuple1+("Word2",5,6.7)

print(tuple2[5])
# Out:
# 6.7

# %%
print(tuple2[3:5])
# Out:
# ('Word2', 5)

# %%
len(tuple2)
# Out:
# 6

# %%
Ratings=(1,2,3,4,5,6,7,8)
nextratings=Ratings

print(nextratings)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
nextratings[2]=9 
# This will be error, because tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 nextratings[2]=9
#       2 # This will be error, because tuples are immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
Ratings=(9,8,7,6,5)

print(Ratings)
print(nextratings)
# This is what happens 
# Ratings=>(1,2,3,4,5,6,7,8) and then we add another tuples inside Ratings variable
# Ratings=>(9,8,7,6,5)
# nextratings still referencing => (1,2,3,4,5,6,7,8)
# Out:
# (9, 8, 7, 6, 5)
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
nextratings2=Ratings
print(nextratings2)
# It seems that if variable referencing a tuple, it will only referencing the latest updates from a tuple
# Out:
# (9, 8, 7, 6, 5)

# %%
Ratings=(4,5,2,2,4,5,6,6,4,4,2,5,6,6,7,8,9,2)
print(Ratings)
print(nextratings)
print(nextratings2)
# Out:
# (4, 5, 2, 2, 4, 5, 6, 6, 4, 4, 2, 5, 6, 6, 7, 8, 9, 2)
# (1, 2, 3, 4, 5, 6, 7, 8)
# (9, 8, 7, 6, 5)

# %%
SortedRatings=sorted(Ratings)
print(SortedRatings)
# Out:
# [2, 2, 2, 2, 4, 4, 4, 4, 5, 5, 5, 6, 6, 6, 6, 7, 8, 9]

# %%
#Tuples also can be nested
NestedTuples=(11,3,4,6,("bird","worm"),(2,2.5),("animal","plant",(97,86)))
print(NestedTuples[6][2][1])
#I am accessing the column6 subcolumn2 and then row 1 tuples which is 86
# Out:
# 86

# %%
#aside from tuples there is Lists -> use [] and is -> mutable
L=["Nawabi",10.2,1991,[4,6],('B',1)] #list also can nest tuples and other data structure
print(L[4][0]) #I am accessing the column4 row0 which is 'B'
# Out:
# B

# %%
print(L[3:5])
# Out:
# [[4, 6], ('B', 1)]

# %%
L.extend(["popcorn",57])
print(L)
# Out:
# ['Nawabi', 10.2, 1991, [4, 6], ('B', 1), 'popcorn', 57, 'popcorn', 57, 'popcorn', 57]

# %%
del L[5:8]

# %%
print(L)
# Out:
# ['Nawabi', 10.2, 1991, [4, 6], ('B', 1), 57, 'popcorn', 57]

# %%
del L[5:8]
print(L)
# Out:
# ['Nawabi', 10.2, 1991, [4, 6], ('B', 1)]

# %%
L.extend(["newextend",99])
print(L)
# Out:
# ['Nawabi', 10.2, 1991, [4, 6], ('B', 1), 'newextend', 99]

# %%
L.append(["newnested",77])
print(L)
# Out:
# ['Nawabi', 10.2, 1991, [4, 6], ('B', 1), 'newextend', 99, ['newnested', 77]]

# %%
#extend is adding more or unnested value, while append can add nested elements
#another mutable example

A=["element1","element2",10,23.2]
print(A)

A[0]="changedelement1"
print(A)
# Out:
# ['element1', 'element2', 10, 23.2]
# ['changedelement1', 'element2', 10, 23.2]

# %%
#we can split a string that has delimiters (separator)
#for example we use separator + here

B=["Z+X+Y+Z"]
print(B)

B=["Z+X+Y+Z".split("+")]
print(B)
# Out:
# ['Z+X+Y+Z']
# [['Z', 'X', 'Y', 'Z']]

# %%
#the side effect of Lists because it's mutable, if we referencing a variable to a list. then the ReferenceVariable will always follow the "current" list value.
C=B
print(C)

B[0]="NewZ"
print(C)
#why it only become NewZ? because the ['Z', 'X', 'Y', 'Z'] is inside [] so python consider it 1 element, I got wrong code above B=["Z+X+Y+Z".split("+")] it should not use []
# Out:
# [['Z', 'X', 'Y', 'Z']]
# ['NewZ']

# %%
B=["Z+X+Y+Z"]
print(B)

B="Z+X+Y+Z".split("+")
print(B)
# Out:
# ['Z+X+Y+Z']
# ['Z', 'X', 'Y', 'Z']

# %%
C=B
print(C)

B[0]="NewZ"
print(C)
#now the code is correct
# Out:
# ['Z', 'X', 'Y', 'Z']
# ['NewZ', 'X', 'Y', 'Z']

# %%
#to clone use -> ClonedVariable = TargetVariable[:] -> if we have data change inside target variable then cloned variable will not change, because we clone it thus not referencing
B=["Z+X+Y+Z"]
print(B)

C=B[:]
print(C)
# Out:
# ['Z+X+Y+Z']
# ['Z+X+Y+Z']

# %%
help(B)
#to see the help for tuple/lists commands
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...
